# %% [markdown]
# # 🔄 Lesson 5: Loops and Iteration
#
# ### Exercise 1: The Interactive Data Collector (Indefinite Loops)
# **Goal:** Create a program that continuously asks the user for numbers until they type "done". It should calculate the total sum and handle errors gracefully.
#
# **Requirements:**
# * Use a `while True` loop to keep asking for input.
# * If the user types "done", use the `break` statement to exit the loop.
# * If the user types anything else, try to convert it to a `float`.
# * Use a `try/except` block to catch cases where the user types something that isn't a number (and isn't "done").
# * Use a `continue` statement to skip the rest of the loop if a negative number is entered (we only want positive data).
# * After the loop finishes, print the total count of valid numbers entered and their sum.
#
#
# ### Exercise 2: The Vocabulary Analyzer
# **Goal:** Use a `for` loop to analyze a list of words. This mimics the "word counting" tasks you will perform in your Natural Language Processing studies.
#
# **Requirements:**
# * Create a list of words: `words = ["algorithm", "data", "processing", "python", "loop", "master", "science"]`.
# * Initialize a variable `longest_word = None`.
# * Use a `for` loop to iterate through the list.
# * Inside the loop, use the "Maximum" idiom logic:
#     * If `longest_word` is `None` OR the current word is longer than the `longest_word`, update the variable.
# * Simultaneously, keep a `count` of how many words have more than 6 characters.
# * After the loop, print the longest word found and the total count of "long" words.

# %%
# solution for Exercise 1

# Initialize variables
total_sum = 0
count = 0

while True:
    user_input = input("Enter a number (or type 'done' to finish): ")

    if user_input.lower() == "done":
        break

    try:
        number = float(user_input)
        if number < 0:
            print("Negative numbers are not allowed. Please enter a positive number.")
            continue
        total_sum += number
        count += 1
    except ValueError:
        print("Invalid input. Please enter a valid number or 'done' to finish.")

print(f"Total count of valid numbers entered: {count}")
# Out:
# Total count of valid numbers entered: 4

# %%
# solution for Exercise 2

# Initialize variables
words = ["algorithm", "data", "processing", "python", "loop", "master", "science"]
longest_word = None
count_long_words = 0

# Iterate through the list of words
for word in words:
    if longest_word is None or len(word) > len(longest_word):
        longest_word = word
    if len(word) > 6:
        count_long_words += 1

# Print results
print(f"The longest word is: {longest_word}")
print(f"Total count of words with more than 6 characters: {count_long_words}")
# Out:
# The longest word is: processing
# Total count of words with more than 6 characters: 3
